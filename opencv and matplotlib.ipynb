# %%
from matplotlib import pyplot as plt
import cv2

# %%
path = r"C:\Amala\OpenCV_learning\Images\dogs2.jpg"
img = cv2.imread(path)
plt.imshow(img)
plt.title("My picture")
plt.show()

# %%
import cv2
path = r"C:\Amala\OpenCV_learning\Images\dogs2.jpg"
img = cv2.imread(path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('my picture')
plt.show()

# %%
import cv2
path = r"C:\Amala\OpenCV_learning\Images\dogs2.jpg"
img = cv2.imread(path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.xticks([]), plt.yticks([]) #to hide tick values on x and y axis
plt.title('my picture')
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2

path = r"C:\Amala\OpenCV_learning\Images\dogs2.jpg"
img = cv2.imread(path)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_image)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.title('my picture')
plt.show()

# %%
path = r"C:\Amala\OpenCV_learning\Images\dogs2.jpg"
img = cv2.imread(path)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, "gray")
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.title('my picture')
plt.show()

# %%
path = r"C:\Amala\OpenCV_learning\Images\dogs2.jpg"
gray_image = cv2.imread(path, 0)
plt.imshow(gray_image,"gray")
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.title('my picture')
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2

path = "Images/dogs2.jpg"
image = cv2.imread(path)
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.subplot(121)
plt.imshow(img_rgb)
plt.xticks([]), plt.yticks([])

plt.subplot(122)
plt.imshow(img_gray, "gray")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img1 = cv2.imread("Images/dogs2.jpg")
img2 = cv2.imread("Images/birds.jpg")

img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.subplot(121)
plt.imshow(img1_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(122)
plt.imshow(img2_rgb)
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img1 = cv2.imread("Images/dogs2.jpg")
img2 = cv2.imread("Images/birds.jpg")
img3 = cv2.imread("Images/fish.jpg")
img4 = cv2.imread("Images/elephents.jpg")

img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img3_rgb = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img4_rgb = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)

plt.subplot(221)
plt.imshow(img1_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(222)
plt.imshow(img2_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(223)
plt.imshow(img3_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(224)
plt.imshow(img4_rgb)
plt.xticks([]), plt.yticks([])

plt.show()

# %%
img1 = cv2.imread("Images/dogs2.jpg")
img2 = cv2.imread("Images/birds.jpg")
img3 = cv2.imread("Images/fish.jpg")
img4 = cv2.imread("Images/elephents.jpg")
img5 = cv2.imread("Images/peacock.jpg")
img6 = cv2.imread("Images/whitepeacock.jpg")

img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img3_rgb = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img4_rgb = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)
img5_rgb = cv2.cvtColor(img5, cv2.COLOR_BGR2RGB)
img6_rgb = cv2.cvtColor(img6, cv2.COLOR_BGR2RGB)

plt.subplot(231)
plt.imshow(img1_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(232)
plt.imshow(img2_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(233)
plt.imshow(img3_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(234)
plt.imshow(img4_rgb)
plt.xticks([]), plt.yticks([])

plt.subplot(235)
plt.imshow(img5_rgb)
plt.xticks([]), plt.yticks([])


plt.subplot(236)
plt.imshow(img6_rgb)
plt.xticks([]), plt.yticks([])
plt.show()
